# %%
#Vemos las etiquetas que encontramos en la extracción de los servicios de la columna "servicios":

from TFG_Chollos.utils import conseguir_ruta_general_TFG
import pandas as pd

BASE = conseguir_ruta_general_TFG()
provincias = pd.read_csv( BASE / "data" / "raw" / "inputs" / "urls_busqueda_booking_provincias.csv", sep="|" )

for provincia in provincias.iloc[:,0]:
    ficha_provincia = pd.read_csv(BASE / 'data' / 'raw' / 'fichas' / f'resultados_booking_{provincia}.csv',  sep='|')
    df = pd.read_csv(BASE / 'data' / 'processed' / 'servicios_binarios' / f'servicios_generales_binarios_{provincia}.csv',  sep='|')
    df.info()

    print("="*50)
    print(f'Analizamos {provincia}:')
    print("="*50)

    for col in df.columns:
        print(col, df[col].unique(), '\n')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Parking           815 non-null    bool
#  1   Parking_gratis    815 non-null    bool
#  2   Gimnasio          815 non-null    bool
#  3   Restaurante       815 non-null    bool
#  4   Piscina           815 non-null    bool
#  5   Piscina_interior  815 non-null    bool
#  6   Piscina_infinita  815 non-null    bool
#  7   Aire              815 non-null    bool
#  8   Calefaccion       815 non-null    bool
#  9   Vistas            815 non-null    bool
#  10  Terraza           815 non-null    bool
#  11  Baño_privado      815 non-null    bool
#  12  url_estancia      815 non-null    str
# dtypes: bool(12), str(1)
# memory usage: 157.5 KB
# ...
# Analizamos Huelva:
# ...
# Parking [False  True]
#
# Parking_gratis [False  True]
#
# Gimnasio [False  True]
#
# Restaurante [False  True]
#
# ...

# %%
#Observamos los valores nulos de las bases de datos finales:

from TFG_Chollos.utils import conseguir_ruta_general_TFG
import pandas as pd

BASE = conseguir_ruta_general_TFG()
provincias = pd.read_csv( BASE / "data" / "raw" / "inputs" / "urls_busqueda_booking_provincias.csv", sep="|" )

for provincia in provincias.iloc[:,0]:
    df_1 = pd.read_parquet(BASE / 'data' / 'processed' / 'final' / f'db_final_{provincia}.parquet')
    print(f'Este es el número de valores nulos en {provincia}:\n{df_1.isnull().sum()}')
# Out:
# Este es el número de valores nulos en Huelva:
# provincia              0
# localidad              0
# titulo                 0
# codigo_postal          0
# latitud                0
# longitud               0
# distancia_centro_km    0
# latitud_centro         0
# longitud_centro        0
# tipo                   0
# estrellas              0
# valoracion_clientes    0
# n_valoraciones         0
# url_estancia           0
# Parking                0
# Parking_gratis         0
# Gimnasio               0
# Restaurante            0
# Piscina                0
# Piscina_interior       0
# Piscina_infinita       0
# Aire                   0
# Calefaccion            0
# Vistas                 0
# Terraza                0
# Baño_privado           0
# tamaño_habitacion      0
# fecha_extraccion       0
# fecha_disponible       0
# dias_restantes         0
# precio                 0
# dtype: int64
# Este es el número de valores nulos en Sevilla:
# provincia              0
# ...

# %%
#Observamos las urls de los registros con valores nulos en valoracion_clientes

from TFG_Chollos.utils import conseguir_ruta_general_TFG
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

BASE = conseguir_ruta_general_TFG()
provincias = pd.read_csv( BASE / "data" / "raw" / "inputs" / "urls_busqueda_booking_provincias.csv", sep="|" )

for provincia in provincias.iloc[:,0]:
    df_1 = pd.read_parquet(BASE / 'data' / 'processed' / 'final' / f'db_final_{provincia}.parquet')
    print(df_1[df_1['valoracion_clientes'].isnull()][['url_estancia','valoracion_clientes']])
